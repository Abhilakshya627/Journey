# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Housing.csv')
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0                no             yes        2      yes        furnished
# 1                no             yes        3       no        furnished
# 2                no              no        2      yes   semi-furnished
# 3                no             yes        3      yes        furnished
# 4                no             yes        2       no        furnished
# ..              ...             ...      ...      ...              ...
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished
#
# [545 rows x 13 columns]

# %%
X=list(df['area'])
Y=list(df['price'])
m=len(X)

# %%
def linear_regression_model(X,w,b):
    function_x=np.zeros(m)
    for i in range(m):
        function_x[i]=w*X[i]+b
    return function_x

# %%
w=95
b=90
prediction_y=linear_regression_model(X,w,b)

# %%
#calculate cost function

def calculate_cost_function(X,Y,w,b):
    
    sum_cost=0
    for i in range(m):
        function_x=w*X[i]+b
        sum_cost=sum_cost+(function_x-Y[i])**2
    final_cost=(1/(2*m))*sum_cost
    return  final_cost

# %%
w=100
b=100
j_cost_cal=calculate_cost_function(X,y,w,b)

# %%
def calculate_gradient(X,Y,w,b):
    dw,db=0,0
    
    for i in range(m):
        function_x=w*X[i]+b
        dw=dw+(function_x-Y[i])*X[i]
        db=db+(function_x-Y[i])
    dw=dw/m
    db=db/m
    
    return dw,db

# %%
w=100
b=100
j_dw,j_db=calculate_gradient(X,Y,w,b)
print(j_dw,j_db)
# Out:
# -23599510368.62385 -4251575.119266055

# %%
def gradient_descent_function(X,Y,w1,b1,calculate_gradient,calculate_cost_function,learning_rate,iteration):
    w,b=w1,b1
    for i in range(iteration):
        j_dw,j_db=calculate_gradient(X,Y,w,b)
        w=w-learning_rate*j_dw
        b=b-learning_rate*j_db
        total_jcost=calculate_cost_function(X,Y,w,b)
        print(f"cost at iteration {i}={total_jcost}")
        
    return w,b

# %%
w1,b1=0,0
learning_rate=0.01
iteration=1000
w,b=gradient_descent_function(X,Y,w1,b1,calculate_gradient,calculate_cost_function,learning_rate,iteration)
print(f"w:{w} and b:{b}")
# Out:
# cost at iteration 0=1.1150450234559209e+24
# cost at iteration 1=1.0874375039886792e+35
# cost at iteration 2=1.060513522061961e+46
# cost at iteration 3=1.0342561538947746e+57
# cost at iteration 4=1.0086488947254675e+68
# cost at iteration 5=9.836756484355592e+78
# cost at iteration 6=9.593207174320828e+89
# cost at iteration 7=9.355687927804782e+100
# cost at iteration 8=9.1240494458173e+111
# cost at iteration 9=8.898146125877826e+122
# cost at iteration 10=8.677835970493507e+133
# cost at iteration 11=8.462980497902582e+144
# cost at iteration 12=8.253444655027981e+155
# cost at iteration 13=8.049096732586412e+166
# cost at iteration 14=7.849808282298766e+177
# cost at iteration 15=7.65545403615071e+188
# cost at iteration 16=7.465911827652163e+199
# cost at iteration 17=7.28106251504624e+210
# cost at iteration 18=7.100789906419653e+221
# cost at iteration 19=6.924980686667126e+232
# cost at iteration 20=6.753524346264246e+243
# cost at iteration 21=6.586313111803865e+254
# cost at iteration 22=6.4232418782520826e+265
# cost at iteration 23=6.264208142881825e+276
# cost at iteration 24=6.109111940842156e+287
# cost at iteration 25=5.957855782322502e+298
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[47], line 4
#       2 learning_rate=0.01
#       3 iteration=1000
# ----> 4 w,b=gradient_descent_function(X,Y,w1,b1,calculate_gradient,calculate_cost_function,learning_rate,iteration)
#       5 print(f"w:{w} and b:{b}")
#
# Cell In[45], line 7, in gradient_descent_function(X, Y, w1, b1, calculate_gradient, calculate_cost_function, learning_rate, iteration)
#       5     w=w-learning_rate*j_dw
#       6     b=b-learning_rate*j_db
# ----> 7     total_jcost=calculate_cost_function(X,Y,w,b)
#       8     print(f"cost at iteration {i}={total_jcost}")
#      10 return w,b
#
# Cell In[41], line 8, in calculate_cost_function(X, Y, w, b)
#       6 for i in range(m):
#       7     function_x=w*X[i]+b
# ----> 8     sum_cost=sum_cost+(function_x-Y[i])**2
#       9 final_cost=(1/(2*m))*sum_cost
#      10 return  final_cost
#
# OverflowError: (34, 'Result too large')

# %%
plt.scatter(X,Y,marker='o',c='red',label="True")
plt.plot(X,prediction_y,c='b',label="Predicted")
plt.xlabel("Size")
plt.ylabel("Price")
plt.legend()
plt.show()
